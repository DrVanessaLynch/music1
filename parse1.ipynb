# %%
from mido import MidiFile

mid = MidiFile('data/ZZ_Top_-_Sleeping_Bag.mid')

for i, track in enumerate(mid.tracks):
    print('Track {}: {}'.format(i, track.name))
    for msg in track:
        print(msg)
# Out:
# Track 0:
# <meta message midi_port port=0 time=0>
# sysex data=(126,127,9,1) time=0
# <meta message midi_port port=0 time=0>
# sysex data=(65,16,66,17,72,0,0,0,29,29,16,11) time=0
# <meta message midi_port port=0 time=0>
# <meta message time_signature numerator=4 denominator=4 clocks_per_click=24 notated_32nd_notes_per_beat=8 time=0>
# <meta message key_signature key='C' time=0>
# <meta message set_tempo tempo=508475 time=0>
# <meta message marker text='SLEEPING BAG\\ZZ Top' time=0>
# <meta message marker text='CHORUS 1' time=9245>
# <meta message end_of_track time=0>
# Track 1: * MUTED LYRICS
# <meta message midi_port port=0 time=0>
# <meta message track_name name='* MUTED LYRICS' time=0>
# program_change channel=3 program=118 time=0
# control_change channel=3 control=7 value=0 time=0
# control_change channel=3 control=10 value=64 time=0
# <meta message lyrics text='SLEEPING`BAG' time=304>
# note_on channel=3 note=54 velocity=119 time=0
# ...

# %% [markdown]
# MIDI note
